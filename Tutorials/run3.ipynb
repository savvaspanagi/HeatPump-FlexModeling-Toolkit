# %%
import pandas as pd
import numpy as np
import os
np.random.seed(42)
# %load_ext autoreload
# %autoreload 2

# === Paths ===
path_in = os.path.join("../Data")  # parent directory
file_path = os.path.join(path_in, "dataset4.xlsx")
df = pd.read_excel(file_path)

# Rename columns
rename_mapping = {
        'T_ext': 'OUTDOOR_TEMP',
        'heating_total [kW]': 'PHI_H',
        'GHI': 'PYRANOMETER',
        'T_int': 'INDOOR_TEMP'
    }
df = df.rename(columns=rename_mapping)
df['PHI_H']=df['PHI_H']*1000
# Convert 't' to datetime and set as index

df['Time'] = pd.to_datetime(df['Time'])
df = df.set_index('Time')
df = df.resample("30min").mean()
surface_area = 2100  # m²
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df['OUTDOOR_TEMP']=df['OUTDOOR_TEMP'] + 273
df['INDOOR_TEMP']=df['INDOOR_TEMP']+273

# %%
split_index = int(0.8 * 0.4*len(df))
end_index = int(0.4*len(df)) 
train_df = df.iloc[:split_index]
val_df = df.iloc[split_index:end_index]

# %%
from models import *
from simulate import *
from plot import *

# --- Bounds ---
bounds_3r2c = {
    "R_in_e": (0.00018, 0.102),
    "R_e_a": (0.0003, 0.170),
    "R_in_a": (0.048, 0.272),
    "C_in": (360e3, 2040e3),
    "C_e": (360e3, 2040e3),
    "Ain": (0, 0),
    "Ae": (0, 0),
    "fh": (1,1)
}
param_defaults = {"R_in_e": 0.06, "R_e_a": 0.10, "R_in_a": 0.160, "C_in": 1200e3, "C_e": 1200e3, "Ain": 0, "Ae": 0,  "fh": 1}

# --- Build and Solve Model ---
model, parameters = build_greybox_model(
    train_df=train_df,
    model_type="3R2C",
    bounds=bounds_3r2c,
    show_plot=True,
    initialization=param_defaults
    ,deltaT=1
)
print(parameters['Objective'])
# Out:
# 0.9457941849728064

# %%
parameters
# Out:
# {'R_in_e': 0.10199597641820757,
#  'R_e_a': 0.005069353441585734,
#  'R_in_a': 0.04800003401461921,
#  'C_in': 2039999.958375587,
#  'C_e': 361988.55574125465,
#  'Ain': 0.0,
#  'Ae': 0.0,
#  'fh': 1.0,
#  'Objective': 0.9457941849728064,
#  'Solve_time': 26.009806632995605}

# %%
last_index = max(model.T_in.index_set())

# --- Validation Initialization (from last training value) ---
initialize_validation = {"Tin": model.T_in[last_index](), "Te": model.T_e[last_index]()}

# --- Run Simulation and Validation ---
validation, t_pred, t_true = simulate_and_evaluate(
    val_df=val_df,
    param_dict=parameters,
    model_type="3R2C",
    initializations=initialize_validation,
    show_plot=True
)

# --- Results ---
print(f"Validation RMSE: {validation['RMSE']:.4f}")

# --- Plot Residuals ---
plot_residual(t_pred=t_pred, t_true=t_true)
# Out:
# Validation RMSE: 4.0373

# %%
from models import *  
from train import *  

best_model, best_parameters, best_initialization, all_trials = train_greybox_model(
    train_df=train_df,
    model_type="3R2C",    # ➔ Select the model type you want to train
    bounds=bounds_3r2c,   # ➔ The bounds you want to use
    solver_name="ipopt",  # ➔ What solver you want to use
    num_trials=10,        # ➔ How many trials you want to run
#  parameters: {'R_in_e': 0.005000009745029, 'R_e_a': 0.005000093844079058, 'R_in_a': 0.004999992247647518, 'C_in': 1870821561.0240445, 'C_e': 3964713880.0217953, 'Ain': 676.53706302354, 'Ae': 4019.7610756236713, 'fh': 0.9999999762395549, 'Objective': 1.701562521501524}
#
# === Best result ===
# Best Trial #: 9
# Best RMSE: 1.3133
# Best initialization: {'R_in_e': 0.6352338500451421, 'R_e_a': 0.2439448906843021, 'R_in_a': 0.0804840114681206, 'C_in': 645269729.8313354, 'C_e': 641101148.9499044, 'Ain': 12152.215565793278, 'Ae': 11106.173898070092, 'fh': 0.6408747448032146}
# Best parameters: {'R_in_e': 0.004999990313327744, 'R_e_a': 0.0049999900674597714, 'R_in_a': 0.020806930874235255, 'C_in': 2459275.0375041426, 'C_e': 4999999969.694017, 'Ain': 1.3624749895512178, 'Ae': 0.00010248042199376356, 'fh': 0.03975649686762395, 'Objective': 1.3132718574971611}

# %%
from models import *
from simulate import *
from plot import *

# --- Build and Solve Model ---
model, parameters = build_greybox_model(
    train_df=train_df,
    model_type="3R2C",
    bounds=bounds_3r2c,
    initialization=best_initialization,
    show_plot=True
)

# --- Validation Initialization (from last training value) ---
initialize_validation = {"Tin": model.T_in[last_index](), "Te": model.T_e[last_index]()}

# --- Run Simulation and Validation ---
validation, t_pred, t_true = simulate_and_evaluate(
    val_df=val_df,
    param_dict=parameters,
    model_type="3R2C",
    initializations=initialize_validation,
    show_plot=True
)

# --- Results ---
print(f"Validation RMSE: {validation['RMSE']:.4f}")

# --- Plot Residuals ---
plot_residual(t_pred=t_pred, t_true=t_true)
# Out:
# Validation RMSE: 1.5379

# %% [markdown]
# # 4R2C

# %%
from models import *
from simulate import *
from plot import *

# --- Bounds ---
bounds_4r3c = {
    "R_int_in": (0.002, 1),
    "R_in_e": (0.002, 1),
    "R_e_a": (0.002, 1),
    "R_in_a": (0.002, 1),
    "C_int": (1.2e6, 5e8),
    "C_in": (1.2e6, 5e8),
    "C_e": (1.2e6, 5e8),
    "Aint": (0.0001, 0.3 * surface_area),
    "Ain": (0.0001, 0.3 * surface_area),
    "Ae": (0.0001, 0.3 * surface_area),
    "fh_int": (0,1),
    "fh_in": (0,1),
    "fh_e": (0,1)
}

# --- Build and Solve Model ---
model, parameters = build_greybox_model(
    train_df=train_df,
    model_type="4R3C",
    bounds=bounds_4r3c,
    show_plot=True
)

# --- Validation Initialization (from last training value) ---
initialize_validation = {"Tint": model.T_int[last_index](),"Tin": model.T_in[last_index](), "Te": model.T_e[last_index]()}

# --- Run Simulation and Validation ---
validation, t_pred, t_true = simulate_and_evaluate(
    val_df=val_df,
    param_dict=parameters,
    model_type="4R3C",
    initializations=initialize_validation,
    show_plot=True
)

# --- Results ---
print(f"Validation RMSE: {validation['RMSE']:.4f}")

# --- Plot Residuals ---
plot_residual(t_pred=t_pred, t_true=t_true)
# Out:
# Validation RMSE: 2.0961

# %%
from models import *  
from train import *  

best_model, best_parameters, best_initialization, all_trials = train_greybox_model(
    train_df=train_df,
    model_type="4R3C",    # ➔ Select the model type you want to train
    bounds=bounds_4r3c,   # ➔ The bounds you want to use
    solver_name="ipopt",  # ➔ What solver you want to use
    num_trials=10,        # ➔ How many trials you want to run
    deltaT=1800,          # ➔ The time step of the data in seconds
    show_plot=False        # ➔ If you want to show the plot of the models (True/False
)
all_trials_4r3c=all_trials.copy()
# Out:
# [Trial 1] RMSE = 1.5374, Init: {'R_int_in': 0.17059719294602022, 'R_in_e': 0.2800331583538947, 'R_e_a': 0.17865646330819332, 'R_in_a': 0.0905251286895415, 'C_int': 61373172.504979685, 'C_in': 231036449.49472362, 'C_e': 104119258.7408093, 'Aint': 43712.38338934207, 'Ain': 60410.072552241094, 'Ae': 82847.37946648436, 'fh_int': 0.039312139841098936, 'fh_in': 0.7994103989090426, 'fh_e': 0.6279003894909078}
#  parameters: {'R_int_in': 0.1740405779672111, 'R_in_e': 0.0019999901378656374, 'R_e_a': 0.001999991241614026, 'R_in_a': 0.0019999901602422007, 'C_int': 152955520.7792273, 'C_in': 128077010.36837359, 'C_e': 100500536.61877386, 'Aint': 0.0010505033657529131, 'Ain': 104.98185379502532, 'Ae': 53.28760600167735, 'fh_int': 0.5314160203010492, 'fh_in': 0.46858395392861124, 'fh_e': 2.577033961415672e-08, 'Objective': 1.5373744379689203}
# [Trial 2] RMSE = 1.6205, Init: {'R_int_in': 0.08359551388497416, 'R_in_e': 0.8738314668585637, 'R_e_a': 0.9210306557307496, 'R_in_a': 0.06295580393515401, 'C_int': 139306570.8958252, 'C_in': 403333198.360779, 'C_e': 374431933.5633688, 'Aint': 22142.52240431318, 'Ain': 25121.918879470304, 'Ae': 44456.652397918624, 'fh_int': 0.4845229851910213, 'fh_in': 0.618254771530296, 'fh_e': 0.3689136395697724}
#  parameters: {'R_int_in': 0.001999990197135825, 'R_in_e': 0.007963734277688506, 'R_e_a': 0.9998621607995238, 'R_in_a': 0.0019999900397590607, 'C_int': 168913852.07887608, 'C_in': 359442991.5139185, 'C_e': 406501236.393199, 'Aint': 0.0001566208260280547, 'Ain': 209.59622880946952, 'Ae': 0.00022570146719652948, 'fh_int': 2.8227265334610652e-08, 'fh_in': 0.8281705253231187, 'fh_e': 0.17182944644961595, 'Objective': 1.6205388444434974}
# [Trial 3] RMSE = 1.6364, Init: {'R_int_in': 0.4636096467008816, 'R_in_e': 0.747975996257489, 'R_e_a': 0.0386098364848167, 'R_in_a': 0.2539320704553327, 'C_int': 357018773.43921477, 'C_in': 447729170.63837504, 'C_e': 256424708.12729427, 'Aint': 63853.61827862653, 'Ain': 12860.641450055924, 'Ae': 53689.48407407331, 'fh_int': 0.5326172664550232, 'fh_in': 0.24247050363472966, 'fh_e': 0.26924323094938096}
#  parameters: {'R_int_in': 0.017093016534519053, 'R_in_e': 0.4175226079158269, 'R_e_a': 0.005847109418697524, 'R_in_a': 0.0019999900405429072, 'C_int': 128277184.33213107, 'C_in': 340553354.2365726, 'C_e': 380401790.3314118, 'Aint': 0.0002869870358397636, 'Ain': 195.13873750231275, 'Ae': 0.013622650436565648, 'fh_int': 2.6646090231274866e-07, 'fh_in': 0.717570094437977, 'fh_e': 0.2824296391011207, 'Objective': 1.6273665535398767}
# [Trial 10] RMSE = 1.1426, Init: {'R_int_in': 0.9650968568451795, 'R_in_e': 0.12604862903857364, 'R_e_a': 0.731405740253237, 'R_in_a': 0.9384637759073957, 'C_int': 91599053.40343128, 'C_in': 34368338.16254862, 'C_e': 370870979.86588144, 'Aint': 68936.77362414212, 'Ain': 101019.45322680977, 'Ae': 16772.685281177502, 'fh_int': 0.7952673118598902, 'fh_in': 0.20162732004774453, 'fh_e': 0.1636559428657045}
#  parameters: {'R_int_in': 0.001999997077990621, 'R_in_e': 0.9999959370845412, 'R_e_a': 0.0019999948729118263, 'R_in_a': 0.011296079244072174, 'C_int': 75664105.32553978, 'C_in': 4148103.698923883, 'C_e': 22338469.11736235, 'Aint': 0.0001096326621611988, 'Ain': 1.704491614140822, 'Ae': 9596.27384942187, 'fh_int': -4.720243679613169e-09, 'fh_in': 0.08067015449038434, 'fh_e': 0.9193298502298594, 'Objective': 1.1425699334646515}
#
# === Best result ===
# Best Trial #: 4
# Best RMSE: 1.1284
# Best initialization: {'R_int_in': 0.3785295947784134, 'R_in_e': 0.022031055382170914, 'R_e_a': 0.3234350072520119, 'R_in_a': 0.21302511098255156, 'C_int': 164555679.26634383, 'C_in': 60937351.35144251, 'C_e': 445395007.6330596, 'Aint': 71231.09446712659, 'Ain': 81492.27832942852, 'Ae': 94700.54865396347, 'fh_int': 0.4984421989290573, 'fh_in': 0.08692028808742369, 'fh_e': 0.5371065418185478}
# Best parameters: {'R_int_in': 0.19834106823353678, 'R_in_e': 0.0027026553407811676, 'R_e_a': 0.0020307654636444084, 'R_in_a': 0.03642741960358386, 'C_int': 134087358.69505204, 'C_in': 2666872.4254450426, 'C_e': 220335542.84915614, 'Aint': 0.000618747028631526, 'Ain': 1.636595398896088, 'Ae': 110.61841587001275, 'fh_int': 0.7348745262928688, 'fh_in': 0.056504452721970036, 'fh_e': 0.2086210209851612, 'Objective': 1.1283655430879551}

# %%
from models import *
from simulate import *
from plot import *

# --- Build and Solve Model ---
model, parameters = build_greybox_model(
    train_df=train_df,
    model_type="4R3C",
    bounds=bounds_4r3c,
    initialization=best_initialization,
    show_plot=True
)

# --- Validation Initialization (from last training value) ---
initialize_validation = {"Tint": model.T_int[last_index](),"Tin": model.T_in[last_index](), "Te": model.T_e[last_index]()}

# --- Run Simulation and Validation ---
validation, t_pred, t_true = simulate_and_evaluate(
    val_df=val_df,
    param_dict=parameters,
    model_type="4R3C",
    initializations=initialize_validation,
    show_plot=True
)

# --- Results ---
print(f"Validation RMSE: {validation['RMSE']:.4f}")

# --- Plot Residuals ---
plot_residual(t_pred=t_pred, t_true=t_true)
# Out:
# Validation RMSE: 2.0961
